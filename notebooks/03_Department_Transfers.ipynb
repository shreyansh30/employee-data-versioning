# %%
# %sql
UPDATE employee_db.employee_versioned
SET JobRole = 'Manager'
WHERE JobRole = 'Sales Executive'
  AND JobLevel = 5;

# %%
# %sql
DESCRIBE HISTORY employee_db.employee_versioned;

# %%
# %sql
SELECT Department, COUNT(*)
FROM employee_db.employee_versioned
GROUP BY Department;

# %%
# %sql
SELECT COUNT(*)
FROM employee_db.employee_versioned
WHERE Department = 'Sales'
  AND JobRole = 'Sales Executive';

# %%
# %sql
UPDATE employee_db.employee_versioned
SET Department = 'Research & Development'
WHERE Department = 'Sales'
  AND JobRole = 'Sales Executive';
