# %%
# %sql
SELECT COUNT(*)
FROM employee_db.employee_versioned
WHERE Attrition = 'Yes';

# %%
# %sql
DELETE FROM employee_db.employee_versioned
WHERE Attrition = 'Yes';

# %%
# %sql
SELECT COUNT(*)
FROM employee_db.employee_versioned;

# %%
# %sql
DESCRIBE HISTORY employee_db.employee_versioned;
