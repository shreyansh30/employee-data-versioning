# %%
# %sql
SELECT COUNT(*)
FROM employee_db.employee_versioned;

# %%
# %sql
SELECT COUNT(*)
FROM employee_db.employee_versioned
VERSION AS OF 6;

# %%
# %sql
SELECT *
FROM employee_db.employee_versioned
VERSION AS OF 6
WHERE Attrition = 'Yes';

# %%
# %sql
DESCRIBE HISTORY employee_db.employee_versioned;

# %%
# %sql
SELECT COUNT(*)
FROM employee_db.employee_versioned
VERSION AS OF 6;

# %%
# %sql
SELECT COUNT(*)
FROM employee_db.employee_versioned
VERSION AS OF 5;

# %%
# %sql
SELECT COUNT(*)
FROM employee_db.employee_versioned
VERSION AS OF 6;

# %%
# %sql
SELECT COUNT(*)
FROM employee_db.employee_versioned;

# %%
# %sql
SELECT 'Before Delete (Version 6)' AS Snapshot,
       COUNT(*) AS EmployeeCount
FROM employee_db.employee_versioned VERSION AS OF 6

UNION ALL

SELECT 'Current Version',
       COUNT(*)
FROM employee_db.employee_versioned;

# %%
# %sql
SELECT *
FROM employee_db.employee_versioned
LIMIT 20;
