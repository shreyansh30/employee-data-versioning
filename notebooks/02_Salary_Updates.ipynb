# %%
# %sql
SELECT EmployeeNumber, MonthlyIncome
FROM employee_db.employee_versioned
LIMIT 10;

# %%
# %sql
UPDATE employee_db.employee_versioned
SET MonthlyIncome = ROUND(MonthlyIncome * 1.10)
WHERE Department = 'Research & Development'
AND JobLevel >= 3;

# %%
# %sql
SELECT EmployeeNumber,
       Department,
       JobLevel,
       MonthlyIncome
FROM employee_db.employee_versioned
WHERE Department = 'Research & Development'
AND JobLevel >= 3
LIMIT 20;

# %%
# %sql
DESCRIBE HISTORY employee_db.employee_versioned;

# %%
# %sql
SELECT COUNT(*)
FROM employee_db.employee_versioned
WHERE Department='Research & Development'
AND JobLevel >= 3;
